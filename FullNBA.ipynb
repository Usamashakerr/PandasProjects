# %%
import pandas as pd

# %%
common_player_info=pd.read_csv("D:/Datasets/NBA/csv/common_player_info.csv")

# %%
pd.set_option('display.max_columns',None)

# %%
# common_player_info=pd.read_csv("D:/Data Analysis/SQL/Datasets/NBA/csv/common_player_info.csv")

# %% [markdown]
#  **if you try to replace 2 symbols u should set regex=true to ensure the symbols will change**

# %%
# if you try to replace 2 symbols u should set regex=true to ensure the symbols will changed 
common_player_info['height']=common_player_info['height'].replace("-", ".", regex=True)

# %%
common_player_info
# Out:
#       person_id first_name     last_name   display_first_last  \
# 0         76001       Alaa     Abdelnaby       Alaa Abdelnaby
# 1         76003     Kareem  Abdul-Jabbar  Kareem Abdul-Jabbar
# 2          1505      Tariq   Abdul-Wahad    Tariq Abdul-Wahad
# 3           949    Shareef   Abdur-Rahim  Shareef Abdur-Rahim
# 4         76005        Tom     Abernethy        Tom Abernethy
# ...         ...        ...           ...                  ...
# 4166    1627835       Paul        Zipser          Paul Zipser
# 4167    1627790       Ante         Zizic           Ante Zizic
# 4168      78647        Jim          Zoet             Jim Zoet
# 4169    1627826      Ivica         Zubac          Ivica Zubac
# 4170      78650       Matt         Zunic           Matt Zunic
#
#      display_last_comma_first  display_fi_last          player_slug  \
# 0             Abdelnaby, Alaa     A. Abdelnaby       alaa-abdelnaby
# 1        Abdul-Jabbar, Kareem  K. Abdul-Jabbar  kareem-abdul-jabbar
# ...

# %%
print(common_player_info['height'].unique())
# Out:
# ['6.10' '7.2' '6.6' '6.9' '6.7' '6.3' '6.8' '6.5' '6.0' '6.11' '6.4'
#  '5.10' '6.2' nan '5.11' '7.1' '7.0' '6.1' '7.5' '7.6' '5.5' '7.3' '5.9'
#  '5.8' '5.7' '5.6' '7.4' '7.7']

# %%
print(common_player_info['draft_year'].unique())
# Out:
# ['1990' '1969' '1997' '1996' '1976' '1956' 'Undrafted' '2013' '2020'
#  '2005' '1953' '1985' '2012' '1975' '1970' '2006' '2014' '1986' '2017'
#  '2018' '1968' '2007' '2022' '1981' '2008' '1966' '2016' '2010' '1959'
#  '2021' '1995' '1991' '2019' '1987' '2011' '2004' '1971' '1980' '1994'
#  '1998' '2002' '1974' '1982' '2015' '1978' '1988' '1989' '1984' '1954'
#  '2003' '2001' '1950' '1977' '1955' '1973' '1999' '2009' '1948' '1952'
#  '2000' '1979' '1983' '1993' '1949' '1964' '1972' '1951' '1992' '1965'
#  '1958' '1962' '1967' '1961' '1957' '1960' '1947' '1963']

# %%
common_player_info['draft_year']=common_player_info['draft_year'].replace('Undrafted','0')

# %%
common_player_info
# Out:
#       person_id first_name     last_name   display_first_last  \
# 0         76001       Alaa     Abdelnaby       Alaa Abdelnaby
# 1         76003     Kareem  Abdul-Jabbar  Kareem Abdul-Jabbar
# 2          1505      Tariq   Abdul-Wahad    Tariq Abdul-Wahad
# 3           949    Shareef   Abdur-Rahim  Shareef Abdur-Rahim
# 4         76005        Tom     Abernethy        Tom Abernethy
# ...         ...        ...           ...                  ...
# 4166    1627835       Paul        Zipser          Paul Zipser
# 4167    1627790       Ante         Zizic           Ante Zizic
# 4168      78647        Jim          Zoet             Jim Zoet
# 4169    1627826      Ivica         Zubac          Ivica Zubac
# 4170      78650       Matt         Zunic           Matt Zunic
#
#      display_last_comma_first  display_fi_last          player_slug  \
# 0             Abdelnaby, Alaa     A. Abdelnaby       alaa-abdelnaby
# 1        Abdul-Jabbar, Kareem  K. Abdul-Jabbar  kareem-abdul-jabbar
# ...

# %%
common_player_info['draft_number']=common_player_info['draft_number'].replace('Undrafted','0')

# %%
common_player_info.to_csv('D:/Datasets/NBA/csv/common_player_info_norm.csv')

# %%
draft_combine_stats=pd.read_csv("D:/Datasets/NBAA/csv/draft_combine_stats.csv")

# %%
draft_combine_stats
# Out:
#       season  player_id first_name   last_name        player_name position  \
# 0       2001      12033       Adam  Allenspach    Adam Allenspach        C
# 1       2001       2240    Gilbert      Arenas     Gilbert Arenas       SG
# 2       2001       2220    Brandon   Armstrong  Brandon Armstrong       SG
# 3       2001       2203      Shane     Battier      Shane Battier    SF-PF
# 4       2001      12034     Cookie     Belcher     Cookie Belcher    SG-PG
# ...      ...        ...        ...         ...                ...      ...
# 1197    2023    1641705     Victor  Wembanyama  Victor Wembanyama        C
# 1198    2023    1641727      Dariq   Whitehead    Dariq Whitehead       SG
# 1199    2023    1641715        Cam    Whitmore       Cam Whitmore       SF
# 1200    2023    1630592      Jalen      Wilson       Jalen Wilson       SF
# 1201    2023    1631209     Isaiah        Wong        Isaiah Wong       SG
#
#       height_wo_shoes height_wo_shoes_ft_in  height_w_shoes  \
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
print(draft_combine_stats['height_w_shoes'])
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1197   NaN
# 1198   NaN
# 1199   NaN
# 1200   NaN
# 1201   NaN
# Name: height_w_shoes, Length: 1202, dtype: float64

# %%
draft_combine_stats
# Out:
#       season  player_id first_name   last_name        player_name position  \
# 0       2001      12033       Adam  Allenspach    Adam Allenspach        C
# 1       2001       2240    Gilbert      Arenas     Gilbert Arenas       SG
# 2       2001       2220    Brandon   Armstrong  Brandon Armstrong       SG
# 3       2001       2203      Shane     Battier      Shane Battier    SF-PF
# 4       2001      12034     Cookie     Belcher     Cookie Belcher    SG-PG
# ...      ...        ...        ...         ...                ...      ...
# 1197    2023    1641705     Victor  Wembanyama  Victor Wembanyama        C
# 1198    2023    1641727      Dariq   Whitehead    Dariq Whitehead       SG
# 1199    2023    1641715        Cam    Whitmore       Cam Whitmore       SF
# 1200    2023    1630592      Jalen      Wilson       Jalen Wilson       SF
# 1201    2023    1631209     Isaiah        Wong        Isaiah Wong       SG
#
#       height_wo_shoes height_wo_shoes_ft_in  height_w_shoes  \
# ...

# %%
print(draft_combine_stats['height_w_shoes'].isnull().sum())
# Out:
# 194

# %%
print(draft_combine_stats['height_wo_shoes_ft_in'].isnull().sum())
# Out:
# 49

# %%
print(draft_combine_stats['height_w_shoes_ft_in'].isnull().sum())
# Out:
# 194

# %%
print(draft_combine_stats['weight'].isnull().sum())
# Out:
# 50

# %%
print(draft_combine_stats['modified_lane_agility_time'].isnull().sum())
# Out:
# 791

# %%
draft_combine_stats=draft_combine_stats.drop(columns=['modified_lane_agility_time'])

# %%
draft_combine_stats
# Out:
#       season  player_id first_name   last_name        player_name position  \
# 0       2001      12033       Adam  Allenspach    Adam Allenspach        C
# 1       2001       2240    Gilbert      Arenas     Gilbert Arenas       SG
# 2       2001       2220    Brandon   Armstrong  Brandon Armstrong       SG
# 3       2001       2203      Shane     Battier      Shane Battier    SF-PF
# 4       2001      12034     Cookie     Belcher     Cookie Belcher    SG-PG
# ...      ...        ...        ...         ...                ...      ...
# 1197    2023    1641705     Victor  Wembanyama  Victor Wembanyama        C
# 1198    2023    1641727      Dariq   Whitehead    Dariq Whitehead       SG
# 1199    2023    1641715        Cam    Whitmore       Cam Whitmore       SF
# 1200    2023    1630592      Jalen      Wilson       Jalen Wilson       SF
# 1201    2023    1631209     Isaiah        Wong        Isaiah Wong       SG
#
#       height_wo_shoes height_wo_shoes_ft_in  height_w_shoes  \
# ...

# %%
print(draft_combine_stats['spot_fifteen_corner_left'].isnull().sum())
# Out:
# 1128

# %%
draft_combine_stats=draft_combine_stats.drop(columns=['spot_fifteen_corner_left'])

# %%
print(draft_combine_stats['spot_fifteen_break_left'].isnull().sum())
# Out:
# 1126

# %%
draft_combine_stats=draft_combine_stats.drop(columns=['spot_fifteen_break_left'])

# %%
print(draft_combine_stats['spot_fifteen_top_key'].isnull().sum())
# Out:
# 1126

# %%
draft_combine_stats=draft_combine_stats.drop(columns=['spot_fifteen_top_key'])

# %%
print(draft_combine_stats['spot_fifteen_break_right'].isnull().sum())
# Out:
# 1126

# %%
print(draft_combine_stats['off_drib_college_break_left'].isnull().sum())
# Out:
# 1092

# %%
draft_combine_stats=draft_combine_stats.drop(columns=['spot_fifteen_corner_right','spot_college_corner_left','spot_college_break_left','spot_college_top_key','spot_college_break_right', 'spot_college_corner_right','spot_nba_corner_left','spot_nba_break_left','spot_nba_top_key','spot_nba_break_right','spot_nba_corner_right','off_drib_fifteen_break_left','off_drib_fifteen_top_key','off_drib_fifteen_break_right','off_drib_college_top_key','off_drib_college_top_key','off_drib_college_break_right','on_move_fifteen','on_move_college'])

# %%
draft_combine_stats
# Out:
#       season  player_id first_name   last_name        player_name position  \
# 0       2001      12033       Adam  Allenspach    Adam Allenspach        C
# 1       2001       2240    Gilbert      Arenas     Gilbert Arenas       SG
# 2       2001       2220    Brandon   Armstrong  Brandon Armstrong       SG
# 3       2001       2203      Shane     Battier      Shane Battier    SF-PF
# 4       2001      12034     Cookie     Belcher     Cookie Belcher    SG-PG
# ...      ...        ...        ...         ...                ...      ...
# 1197    2023    1641705     Victor  Wembanyama  Victor Wembanyama        C
# 1198    2023    1641727      Dariq   Whitehead    Dariq Whitehead       SG
# 1199    2023    1641715        Cam    Whitmore       Cam Whitmore       SF
# 1200    2023    1630592      Jalen      Wilson       Jalen Wilson       SF
# 1201    2023    1631209     Isaiah        Wong        Isaiah Wong       SG
#
#       height_wo_shoes height_wo_shoes_ft_in  height_w_shoes  \
# ...

# %%
print(draft_combine_stats['bench_press'].isnull().sum())
# Out:
# 394

# %%
draft_combine_stats.to_csv('D:/Datasets/NBA/csv/draft_combine_stats_norm.csv')

# %%
draft_history=pd.read_csv('D:/Datasets/NBA/csv/draft_history.csv')

# %%
draft_history
# Out:
#       person_id           player_name  season  round_number  round_pick  \
# 0         79299      Clifton McNeeley    1947             1           1
# 1         78109            Glen Selbo    1947             1           2
# 2         76649          Eddie Ehlers    1947             1           3
# 3         79302            Walt Dropo    1947             1           4
# 4         77048            Dick Holub    1947             1           5
# ...         ...                   ...     ...           ...         ...
# 7985    1641771         Jalen Slawson    2023             2          24
# 7986    1631209           Isaiah Wong    2023             2          25
# 7987    1641844       Tarik Biberovic    2023             2          26
# 7988    1631218  Trayce Jackson-Davis    2023             2          27
# 7989    1641753      Chris Livingston    2023             2          28
#
#       overall_pick draft_type     team_id   team_city     team_name  \
# ...

# %%
pd.set_option("display.max_columns",None)

# %%
game=pd.read_csv('D:/Datasets/NBA/csv/game.csv')

# %%
game
# Out:
#        season_id  team_id_home team_abbreviation_home  \
# 0          21946    1610610035                    HUS
# 1          21946    1610610034                    BOM
# 2          21946    1610610032                    PRO
# 3          21946    1610610025                    CHS
# 4          21946    1610610028                    DEF
# ...          ...           ...                    ...
# 65693      42022    1610612748                    MIA
# 65694      42022    1610612748                    MIA
# 65695      42022    1610612743                    DEN
# 65696      32022    1610616834                    LBN
# 65697      32022    1610616834                    LBN
#
#                 team_name_home   game_id            game_date matchup_home  \
# 0              Toronto Huskies  24600001  1946-11-01 00:00:00  HUS vs. NYK
# 1            St. Louis Bombers  24600003  1946-11-02 00:00:00  BOM vs. PIT
# 2      Providence Steamrollers  24600002  1946-11-02 00:00:00  PRO vs. BOS
# ...

# %%
print(game['dreb_away'].isna().sum())
# Out:
# 18998

# %%
game_info=pd.read_csv('D:/Datasets/NBA/csv/game_info.csv')

# %%
game_info
# Out:
#         game_id            game_date  attendance game_time
# 0      24600001  1946-11-01 00:00:00         NaN       NaN
# 1      24600003  1946-11-02 00:00:00         NaN       NaN
# 2      24600002  1946-11-02 00:00:00         NaN       NaN
# 3      24600004  1946-11-02 00:00:00         NaN       NaN
# 4      24600005  1946-11-02 00:00:00         NaN       NaN
# ...         ...                  ...         ...       ...
# 58048  42200403  2023-06-07 00:00:00     20019.0      2:24
# 58049  42200404  2023-06-09 00:00:00     20184.0      2:29
# 58050  42200405  2023-06-12 00:00:00     19537.0      2:22
# 58051  32200001  2023-02-19 00:00:00     17886.0      0:00
# 58052  32200001  2023-02-19 00:00:00     17886.0      0:00
#
# [58053 rows x 4 columns]

# %%
print(game_info['game_date'].isna().sum())
# Out:
# 0

# %%
game_summary=pd.read_csv('D:/Datasets/NBA/csv/game_summary.csv')

# %%
game_summary
# Out:
#              game_date_est  game_sequence   game_id  game_status_id  \
# 0      1946-11-01 00:00:00            NaN  24600001               3
# 1      1946-11-02 00:00:00            NaN  24600003               3
# 2      1946-11-02 00:00:00            NaN  24600002               3
# 3      1946-11-02 00:00:00            NaN  24600004               3
# 4      1946-11-02 00:00:00            NaN  24600005               3
# ...                    ...            ...       ...             ...
# 58105  2023-06-07 00:00:00            1.0  42200403               3
# 58106  2023-06-09 00:00:00            1.0  42200404               3
# 58107  2023-06-12 00:00:00            1.0  42200405               3
# 58108  2023-02-19 00:00:00            1.0  32200001               3
# 58109  2023-02-19 00:00:00            1.0  32200001               3
#
#       game_status_text         gamecode  home_team_id  visitor_team_id  \
# 0                  NaN  19461101/NYKHUS    1610610035       1610612752
# ...

# %%
print(game_summary['game_status_text'].unique())
# Out:
# [nan 'Final' '7:00 pm ET' '8:00 pm ET' '4th Qtr' 'Final               ']

# %%
print(game_summary['live_pc_time'].isna().sum())
# Out:
# 56086

# %%
game_summary=game_summary.drop(columns=['live_pc_time'])

# %%
print(game_summary['natl_tv_broadcaster_abbreviation'].isna().sum())
# Out:
# 51907

# %%
game_summary=game_summary.drop(columns=['natl_tv_broadcaster_abbreviation'])

# %%
print(game_summary['live_period_time_bcast'].isna().sum())
# Out:
# 0

# %%
game_summary.to_csv('D:/Datasets/NBA/csv/game_summary_norm.csv')

# %%
inactive_players=pd.read_csv('D:/Datasets/NBA/csv/inactive_players.csv')

# %%
inactive_players
# Out:
#          game_id  player_id first_name   last_name  jersey_num     team_id  \
# 0       29600034        184      Bobby      Phills        14.0  1610612739
# 1       29600034        781       Will      Perdue        41.0  1610612759
# 2       29600132        120     Steven       Smith         8.0  1610612737
# 3       29600203        698      Eddie     Johnson         8.0  1610612754
# 4       29600213         32   Clifford      Rozier        44.0  1610612753
# ...          ...        ...        ...         ...         ...         ...
# 110186  32200001    1629627       Zion  Williamson         1.0  1610616834
# 110187  32200001     201939    Stephen       Curry        30.0  1610616834
# 110188  32200001     201142      Kevin      Durant        35.0  1610616833
# 110189  32200001    1629627       Zion  Williamson         1.0  1610616834
# 110190  32200001     201939    Stephen       Curry        30.0  1610616834
#
#           team_city  team_name team_abbreviation
# ...

# %%
print(inactive_players['team_city'].unique())
# Out:
# ['Cleveland' 'San Antonio' 'Atlanta' 'Indiana' 'Orlando' 'Toronto'
#  'Los Angeles' 'Miami' 'New Jersey' 'Houston' 'Charlotte' 'New York'
#  'Philadelphia' 'Boston' 'Vancouver' 'Dallas' 'Utah' 'Sacramento'
#  'Portland' 'Seattle' 'Minnesota' 'Chicago' 'Detroit' 'Golden State'
#  'Denver' 'Washington' 'Memphis' 'Milwaukee' 'Phoenix' 'New Orleans'
#  'New Orleans/Oklahoma City' 'Real Madrid' 'East NBA All Stars'
#  'Oklahoma City' 'Moscow' 'Vilnius' 'Brooklyn' 'West NBA All Stars' 'LA'
#  'Team' 'Adelaide']

# %%
filtered_players = inactive_players[inactive_players['team_city'] == 'Team']
filtered_players
# Out:
#          game_id  player_id first_name   last_name  jersey_num     team_id  \
# 67529   31700001     202322       John        Wall         2.0  1610616833
# 67530   31700001     202326   DeMarcus     Cousins         0.0  1610616833
# 67531   31700001     204001   Kristaps   Porzingis         6.0  1610616833
# 67532   31700001     201567      Kevin        Love         0.0  1610616833
# 91531   32000001     203076    Anthony       Davis         3.0  1610616833
# 91532   32000001    1626164      Devin      Booker         1.0  1610616833
# 91533   32000001     203954       Joel      Embiid        21.0  1610616833
# 91534   32000001     201142      Kevin      Durant         7.0  1610616833
# 91535   32000001    1627732        Ben     Simmons        25.0  1610616834
# 101458  32100001     201142      Kevin      Durant         7.0  1610616833
# 101459  32100001     203110   Draymond       Green        23.0  1610616833
# ...

# %%
# inactive_players.drop(inactive_players[inactive_players['team_city']=='Team'].index,inplace=True)

# %%
inactive_players['team_city'].unique()
# Out:
# array(['Cleveland', 'San Antonio', 'Atlanta', 'Indiana', 'Orlando',
#        'Toronto', 'Los Angeles', 'Miami', 'New Jersey', 'Houston',
#        'Charlotte', 'New York', 'Philadelphia', 'Boston', 'Vancouver',
#        'Dallas', 'Utah', 'Sacramento', 'Portland', 'Seattle', 'Minnesota',
#        'Chicago', 'Detroit', 'Golden State', 'Denver', 'Washington',
#        'Memphis', 'Milwaukee', 'Phoenix', 'New Orleans',
#        'New Orleans/Oklahoma City', 'Real Madrid', 'East NBA All Stars',
#        'Oklahoma City', 'Moscow', 'Vilnius', 'Brooklyn',
#        'West NBA All Stars', 'LA', 'Team', 'Adelaide'], dtype=object)

# %%
rm=inactive_players[inactive_players['team_city']=='Real Madrid']

# %%
rm
# Out:
#         game_id  player_id first_name last_name  jersey_num  team_id  \
# 17477  10700028      40045     Felipe     Reyes         9.0    12315
#
#          team_city    team_name team_abbreviation
# 17477  Real Madrid  Real Madrid               RMA

# %%
inactive_players['team_city'].unique()
# Out:
# array(['Cleveland', 'San Antonio', 'Atlanta', 'Indiana', 'Orlando',
#        'Toronto', 'Los Angeles', 'Miami', 'New Jersey', 'Houston',
#        'Charlotte', 'New York', 'Philadelphia', 'Boston', 'Vancouver',
#        'Dallas', 'Utah', 'Sacramento', 'Portland', 'Seattle', 'Minnesota',
#        'Chicago', 'Detroit', 'Golden State', 'Denver', 'Washington',
#        'Memphis', 'Milwaukee', 'Phoenix', 'New Orleans',
#        'New Orleans/Oklahoma City', 'Real Madrid', 'East NBA All Stars',
#        'Oklahoma City', 'Moscow', 'Vilnius', 'Brooklyn',
#        'West NBA All Stars', 'LA', 'Team', 'Adelaide'], dtype=object)

# %%
moscow=inactive_players[inactive_players['team_city']=='Moscow']

# %%
moscow
# Out:
#         game_id  player_id first_name     last_name  jersey_num  team_id  \
# 23350  10800026     416497     Andrey  Vorontsevich        20.0    12308
#
#       team_city team_name team_abbreviation
# 23350    Moscow      CSKA               MOS

# %%
# inactive_players.drop(inactive_players[inactive_players['team_city']=='Moscow'].index,inplace=True)

# %%
inactive_players
# Out:
#          game_id  player_id first_name   last_name  jersey_num     team_id  \
# 0       29600034        184      Bobby      Phills        14.0  1610612739
# 1       29600034        781       Will      Perdue        41.0  1610612759
# 2       29600132        120     Steven       Smith         8.0  1610612737
# 3       29600203        698      Eddie     Johnson         8.0  1610612754
# 4       29600213         32   Clifford      Rozier        44.0  1610612753
# ...          ...        ...        ...         ...         ...         ...
# 110186  32200001    1629627       Zion  Williamson         1.0  1610616834
# 110187  32200001     201939    Stephen       Curry        30.0  1610616834
# 110188  32200001     201142      Kevin      Durant        35.0  1610616833
# 110189  32200001    1629627       Zion  Williamson         1.0  1610616834
# 110190  32200001     201939    Stephen       Curry        30.0  1610616834
#
#           team_city  team_name team_abbreviation
# ...

# %%
print(inactive_players[inactive_players['team_name']=='East'])
# Out:
#         game_id  player_id first_name last_name  jersey_num     team_id  \
# 17938  30700001        708      Kevin   Garnett         5.0  1610616833
# 17939  30700001       2406      Caron    Butler         3.0  1610616833
# 17940  30700001        708      Kevin   Garnett         5.0  1610616833
# 17941  30700001       2406      Caron    Butler         3.0  1610616833
# 23767  30800001       2547      Chris      Bosh         4.0  1610616833
# 23768  30800001       2749     Jameer    Nelson        14.0  1610616833
# 48011  31400001       2548     Dwyane      Wade         3.0  1610616833
# 48013  31400001       2548     Dwyane      Wade         3.0  1610616833
# 53141  31500001     202710      Jimmy    Butler        21.0  1610616833
# 53142  31500001       2547      Chris      Bosh         1.0  1610616833
#
#                 team_city team_name team_abbreviation
# 17938  East NBA All Stars      East               EST
# 17939  East NBA All Stars      East               EST
# ...

# %%
# inactive_players.drop(inactive_players[inactive_players['team_city']=='Lietuvos Rytas'].index,inplace=True)

# %%
inactive_players[inactive_players.duplicated()]
# Out:
#          game_id  player_id first_name   last_name  jersey_num     team_id  \
# 17940   30700001        708      Kevin     Garnett         5.0  1610616833
# 17941   30700001       2406      Caron      Butler         3.0  1610616833
# 48013   31400001       2548     Dwyane        Wade         3.0  1610616833
# 48014   31400001     201933      Blake     Griffin        32.0  1610616834
# 110188  32200001     201142      Kevin      Durant        35.0  1610616833
# 110189  32200001    1629627       Zion  Williamson         1.0  1610616834
# 110190  32200001     201939    Stephen       Curry        30.0  1610616834
#
#                  team_city team_name team_abbreviation
# 17940   East NBA All Stars      East               EST
# 17941   East NBA All Stars      East               EST
# 48013   East NBA All Stars      East               EST
# 48014   West NBA All Stars      West               WST
# 110188                Team   Giannis               GNS
# ...

# %%
# inactive_players=inactive_players.drop_duplicates(keep=False)

# %%
inactive_players
# Out:
#          game_id  player_id first_name   last_name  jersey_num     team_id  \
# 0       29600034        184      Bobby      Phills        14.0  1610612739
# 1       29600034        781       Will      Perdue        41.0  1610612759
# 2       29600132        120     Steven       Smith         8.0  1610612737
# 3       29600203        698      Eddie     Johnson         8.0  1610612754
# 4       29600213         32   Clifford      Rozier        44.0  1610612753
# ...          ...        ...        ...         ...         ...         ...
# 110186  32200001    1629627       Zion  Williamson         1.0  1610616834
# 110187  32200001     201939    Stephen       Curry        30.0  1610616834
# 110188  32200001     201142      Kevin      Durant        35.0  1610616833
# 110189  32200001    1629627       Zion  Williamson         1.0  1610616834
# 110190  32200001     201939    Stephen       Curry        30.0  1610616834
#
#           team_city  team_name team_abbreviation
# ...

# %%
inactive_players[inactive_players['player_id'].duplicated()]
# Out:
#          game_id  player_id first_name   last_name  jersey_num     team_id  \
# 23      29600821        770       Mark        West        52.0  1610612739
# 26      29600873        770       Mark        West        41.0  1610612739
# 28      29600961        168      Chris       Mills        50.0  1610612739
# 33      29601087        238     Tyrone        Hill        32.0  1610612739
# 36      29601139        291         Ed    Pinckney        54.0  1610612748
# ...          ...        ...        ...         ...         ...         ...
# 110186  32200001    1629627       Zion  Williamson         1.0  1610616834
# 110187  32200001     201939    Stephen       Curry        30.0  1610616834
# 110188  32200001     201142      Kevin      Durant        35.0  1610616833
# 110189  32200001    1629627       Zion  Williamson         1.0  1610616834
# 110190  32200001     201939    Stephen       Curry        30.0  1610616834
#
#         team_city  team_name team_abbreviation
# ...

# %%
inactive_players.to_csv('D:/Datasets/NBA/csv/inactive_players_norm.csv')

# %%
line_score=pd.read_csv('D:/Datasets/NBA/csv/line_score.csv')

# %%
line_score
# Out:
#              game_date_est  game_sequence   game_id  team_id_home  \
# 0      1946-11-01 00:00:00            NaN  24600001    1610610035
# 1      1946-11-02 00:00:00            NaN  24600003    1610610034
# 2      1946-11-02 00:00:00            NaN  24600002    1610612738
# 3      1946-11-02 00:00:00            NaN  24600004    1610610025
# 4      1946-11-02 00:00:00            NaN  24600005    1610610036
# ...                    ...            ...       ...           ...
# 58048  2023-06-07 00:00:00            1.0  42200403    1610612748
# 58049  2023-06-09 00:00:00            1.0  42200404    1610612748
# 58050  2023-06-12 00:00:00            1.0  42200405    1610612743
# 58051  2023-02-19 00:00:00            1.0  32200001    1610616834
# 58052  2023-02-19 00:00:00            1.0  32200001    1610616834
#
#       team_abbreviation_home team_city_name_home team_nickname_home  \
# 0                        HUS             Toronto            Huskies
# ...

# %%
line_score[line_score.duplicated()]
# Out:
#              game_date_est  game_sequence   game_id  team_id_home  \
# 1614   1951-03-02 00:00:00            1.0  35000001    1610616833
# 1922   1952-02-11 00:00:00            1.0  35100001    1610616834
# 2245   1953-01-13 00:00:00            1.0  35200001    1610616833
# 2540   1954-01-21 00:00:00            1.0  35300004    1610616833
# 2809   1955-01-18 00:00:00            1.0  35400001    1610616833
# 3080   1956-01-24 00:00:00            1.0  35500001    1610616833
# 3339   1957-01-15 00:00:00            1.0  35600001    1610616834
# 3590   1958-01-21 00:00:00            1.0  35700001    1610616834
# 3833   1959-01-23 00:00:00            1.0  35800001    1610616833
# 4132   1962-01-16 00:00:00            1.0  36103001    1610616834
# 4456   1963-01-16 00:00:00            1.0  36200001    1610616833
# 5450   1967-01-10 00:00:00            1.0  36600001    1610616833
# 6407   1969-01-14 00:00:00            1.0  36800001    1610616833
# ...

# %%
# line_score['pts_ot1_home'].isnull().value_counts()

# %%
# line_score=line_score.drop(columns=['pts_ot1_home','pts_ot2_home','pts_ot3_home','pts_ot4_home','pts_ot5_home','pts_ot6_home','pts_ot7_home','pts_ot8_home','pts_ot9_home','pts_ot10_home','pts_ot1_away','pts_ot2_away','pts_ot3_away','pts_ot9_away','pts_ot4_away','pts_ot5_away','pts_ot6_away','pts_ot7_away','pts_ot8_away','pts_ot10_away'])

# %%
line_score
# Out:
#              game_date_est  game_sequence   game_id  team_id_home  \
# 0      1946-11-01 00:00:00            NaN  24600001    1610610035
# 1      1946-11-02 00:00:00            NaN  24600003    1610610034
# 2      1946-11-02 00:00:00            NaN  24600002    1610612738
# 3      1946-11-02 00:00:00            NaN  24600004    1610610025
# 4      1946-11-02 00:00:00            NaN  24600005    1610610036
# ...                    ...            ...       ...           ...
# 58048  2023-06-07 00:00:00            1.0  42200403    1610612748
# 58049  2023-06-09 00:00:00            1.0  42200404    1610612748
# 58050  2023-06-12 00:00:00            1.0  42200405    1610612743
# 58051  2023-02-19 00:00:00            1.0  32200001    1610616834
# 58052  2023-02-19 00:00:00            1.0  32200001    1610616834
#
#       team_abbreviation_home team_city_name_home team_nickname_home  \
# 0                        HUS             Toronto            Huskies
# ...

# %%
line_score['team_city_name_home'].unique()
# Out:
# array(['Toronto', 'St. Louis', 'Boston', 'Chicago', 'Washington',
#        'New York', 'Pittsburgh', 'Detroit', 'Cleveland', 'Providence',
#        'Philadelphia', 'Baltimore', 'Indianapolis', 'Minneapolis',
#        'Ft. Wayne Zollner', 'Rochester', 'Denver', 'Anderson',
#        'Sheboygan', 'Tri-Cities', 'Waterloo', 'Syracuse',
#        'East NBA All Stars', 'Milwaukee', 'West NBA All Stars',
#        'Cincinnati', 'Los Angeles', 'San Francisco', 'Seattle',
#        'San Diego', 'Phoenix', 'Atlanta', 'Houston', 'Portland',
#        'Buffalo', 'Golden State', 'Kansas City-Omaha', 'Capital',
#        'New Orleans', 'Kansas City', 'Indiana', 'San Antonio',
#        'New Jersey', 'Utah', 'Dallas', 'Sacramento', 'Charlotte', 'Miami',
#        'Orlando', 'Minnesota', 'Vancouver', 'Memphis',
#        'New Orleans/Oklahoma City', 'Barcelona', 'Tel Aviv', 'Moscow',
#        'Istanbul', 'Lottomatica', 'Zalgiris Kaunas', 'Oklahoma City',
# ...

# %%
line_score[line_score['team_city_name_home']=='Team']
# Out:
#              game_date_est  game_sequence   game_id  team_id_home  \
# 52195  2018-02-18 00:00:00            1.0  31700001    1610616834
# 53393  2019-02-17 00:00:00            1.0  31800001    1610616833
# 53394  2019-02-17 00:00:00            1.0  31800001    1610616833
# 54427  2020-02-16 00:00:00            1.0  31900001    1610616833
# 55543  2021-03-07 00:00:00            1.0  32000001    1610616833
# 56799  2022-02-20 00:00:00            1.0  32100001    1610616833
# 58051  2023-02-19 00:00:00            1.0  32200001    1610616834
# 58052  2023-02-19 00:00:00            1.0  32200001    1610616834
#
#       team_abbreviation_home team_city_name_home team_nickname_home  \
# 52195                    STP                Team            Stephen
# 53393                    AST                Team            Giannis
# 53394                    AST                Team            Giannis
# 54427                    GNS                Team            Giannis
# ...

# %%
# line_score.drop(line_score[line_score['team_city_name_home']=='Team'].index,inplace=True)

# %%
line_score
# Out:
#              game_date_est  game_sequence   game_id  team_id_home  \
# 0      1946-11-01 00:00:00            NaN  24600001    1610610035
# 1      1946-11-02 00:00:00            NaN  24600003    1610610034
# 2      1946-11-02 00:00:00            NaN  24600002    1610612738
# 3      1946-11-02 00:00:00            NaN  24600004    1610610025
# 4      1946-11-02 00:00:00            NaN  24600005    1610610036
# ...                    ...            ...       ...           ...
# 58048  2023-06-07 00:00:00            1.0  42200403    1610612748
# 58049  2023-06-09 00:00:00            1.0  42200404    1610612748
# 58050  2023-06-12 00:00:00            1.0  42200405    1610612743
# 58051  2023-02-19 00:00:00            1.0  32200001    1610616834
# 58052  2023-02-19 00:00:00            1.0  32200001    1610616834
#
#       team_abbreviation_home team_city_name_home team_nickname_home  \
# 0                        HUS             Toronto            Huskies
# ...

# %%
line_score.to_csv("D:/Datasets/NBA/csv/line_score_norm.csv")

# %%
officials=pd.read_csv("D:/Datasets/NBA/csv/officials.csv")

# %%
officials
# Out:
#         game_id  official_id first_name  last_name  jersey_num
# 0      29600059         1140      Bruce  Alexander         9.0
# 1      29600059         1165       Luis     Grillo         8.0
# 2      29600059         1153        Joe   Crawford        17.0
# 3      29600114         1147       Mike   Callahan        24.0
# 4      29600114         1142       Dick    Bavetta        27.0
# ...         ...          ...        ...        ...         ...
# 70966  32200001       200834       Mark    Lindsay        29.0
# 70967  32200001         1193    Michael      Smith        38.0
# 70968  32200001       101284       John      Goble        10.0
# 70969  32200001       200834       Mark    Lindsay        29.0
# 70970  32200001         1193    Michael      Smith        38.0
#
# [70971 rows x 5 columns]

# %%
officials[officials['official_id'].duplicated()]
# Out:
#         game_id  official_id first_name last_name  jersey_num
# 12     29600188         1165       Luis    Grillo         8.0
# 13     29600188         1153        Joe  Crawford        17.0
# 16     29600213         1157      Terry    Durham        31.0
# 22     29600365         1158       Hugh     Evans        25.0
# 23     29600689         1163     Bernie     Fryer         7.0
# ...         ...          ...        ...       ...         ...
# 70966  32200001       200834       Mark   Lindsay        29.0
# 70967  32200001         1193    Michael     Smith        38.0
# 70968  32200001       101284       John     Goble        10.0
# 70969  32200001       200834       Mark   Lindsay        29.0
# 70970  32200001         1193    Michael     Smith        38.0
#
# [70736 rows x 5 columns]

# %%
other_stats=pd.read_csv("D:/Datasets/NBA/csv/other_stats.csv")

# %%
other_stats
# Out:
#         game_id  league_id  team_id_home team_abbreviation_home  \
# 0      29600012          0    1610612756                    PHX
# 1      29600005          0    1610612737                    ATL
# 2      29600002          0    1610612739                    CLE
# 3      29600007          0    1610612754                    IND
# 4      29600013          0    1610612746                    LAC
# ...         ...        ...           ...                    ...
# 28266  42200402          0    1610612743                    DEN
# 28267  42200403          0    1610612748                    MIA
# 28268  42200404          0    1610612743                    DEN
# 28269  32200001          0    1610616834                    LBN
# 28270  32200001          0    1610616834                    LBN
#
#       team_city_home  pts_paint_home  pts_2nd_chance_home  pts_fb_home  \
# 0            Phoenix              44                   18            2
# ...

# %%
# other_stats.drop(other_stats[other_stats['team_city_home']=='Team'].index,inplace=True)

# %%
other_stats['league_id'].value_counts()
# Out:
# league_id
# 0    28271
# Name: count, dtype: int64

# %%
other_stats=other_stats.drop(columns='league_id')

# %%
other_stats
# Out:
#         game_id  team_id_home team_abbreviation_home team_city_home  \
# 0      29600012    1610612756                    PHX        Phoenix
# 1      29600005    1610612737                    ATL        Atlanta
# 2      29600002    1610612739                    CLE      Cleveland
# 3      29600007    1610612754                    IND        Indiana
# 4      29600013    1610612746                    LAC    Los Angeles
# ...         ...           ...                    ...            ...
# 28266  42200402    1610612743                    DEN         Denver
# 28267  42200403    1610612748                    MIA          Miami
# 28268  42200404    1610612743                    DEN         Denver
# 28269  32200001    1610616834                    LBN           Team
# 28270  32200001    1610616834                    LBN           Team
#
#        pts_paint_home  pts_2nd_chance_home  pts_fb_home  largest_lead_home  \
# ...

# %%
other_stats.to_csv('D:/Datasets/NBA/csv/other_stats_norm.csv')

# %%
play_by_play=pd.read_csv('D:/Datasets/NBAA/csv/play_by_play.csv')

# %%
play_by_play
# Out:
#            game_id  eventnum  eventmsgtype  eventmsgactiontype  period  \
# 0         29600012         0            12                   0       1
# 1         29600012         2            10                   0       1
# 2         29600012         3             2                   1       1
# 3         29600012         4             4                   0       1
# 4         29600012         5             2                   1       1
# ...            ...       ...           ...                 ...     ...
# 13592894  32200001       638             1                  79       4
# 13592895  32200001       639             2                   1       4
# 13592896  32200001       640             4                   0       4
# 13592897  32200001       641             1                  79       4
# 13592898  32200001       642            13                   0       4
#
#          wctimestring pctimestring  \
# 0            14:43 PM        12:00
# 1            14:50 PM        12:00
# ...

# %%
# play_by_play.drop(play_by_play[play_by_play['player1_team_city']=='Team'].index,inplace=True)

# %%
(play_by_play['person2type']==0).value_counts()
# Out:
# person2type
# True     9660036
# False    3932863
# Name: count, dtype: int64

# %%
play_by_play.to_csv('D:/Datasets/NBA/csv/play_by_play_norm.csv')

# %%
player=pd.read_csv('D:/Datasets/NBA/csv/player.csv')

# %%
player
# Out:
#            id            full_name first_name     last_name  is_active
# 0       76001       Alaa Abdelnaby       Alaa     Abdelnaby          0
# 1       76002      Zaid Abdul-Aziz       Zaid    Abdul-Aziz          0
# 2       76003  Kareem Abdul-Jabbar     Kareem  Abdul-Jabbar          0
# 3          51   Mahmoud Abdul-Rauf    Mahmoud    Abdul-Rauf          0
# 4        1505    Tariq Abdul-Wahad      Tariq   Abdul-Wahad          0
# ...       ...                  ...        ...           ...        ...
# 4826  1627790           Ante Zizic       Ante         Zizic          0
# 4827    78647             Jim Zoet        Jim          Zoet          0
# 4828    78648            Bill Zopf       Bill          Zopf          0
# 4829  1627826          Ivica Zubac      Ivica         Zubac          1
# 4830    78650           Matt Zunic       Matt         Zunic          0
#
# [4831 rows x 5 columns]

# %%
player[player['id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, full_name, first_name, last_name, is_active]
# Index: []

# %%
team=pd.read_csv('D:/Datasets/NBA/csv/team.csv')

# %%
team
# Out:
#             id               full_name abbreviation       nickname  \
# 0   1610612737           Atlanta Hawks          ATL          Hawks
# 1   1610612738          Boston Celtics          BOS        Celtics
# 2   1610612739     Cleveland Cavaliers          CLE      Cavaliers
# 3   1610612740    New Orleans Pelicans          NOP       Pelicans
# 4   1610612741           Chicago Bulls          CHI          Bulls
# 5   1610612742        Dallas Mavericks          DAL      Mavericks
# 6   1610612743          Denver Nuggets          DEN        Nuggets
# 7   1610612744   Golden State Warriors          GSW       Warriors
# 8   1610612745         Houston Rockets          HOU        Rockets
# 9   1610612746    Los Angeles Clippers          LAC       Clippers
# 10  1610612747      Los Angeles Lakers          LAL         Lakers
# 11  1610612748              Miami Heat          MIA           Heat
# 12  1610612749         Milwaukee Bucks          MIL          Bucks
# ...

# %%
team_details=pd.read_csv('D:/Datasets/NBA/csv/team_details.csv')

# %%
team_details
# Out:
#        team_id abbreviation       nickname  yearfounded           city  \
# 0   1610612737          ATL          Hawks       1949.0        Atlanta
# 1   1610612741          CHI          Bulls       1966.0        Chicago
# 2   1610612742          DAL      Mavericks       1980.0         Dallas
# 3   1610612743          DEN        Nuggets       1976.0         Denver
# 4   1610612744          GSW       Warriors       1946.0   Golden State
# 5   1610612745          HOU        Rockets       1967.0        Houston
# 6   1610612746          LAC       Clippers       1970.0    Los Angeles
# 7   1610612747          LAL         Lakers       1948.0    Los Angeles
# 8   1610612748          MIA           Heat       1988.0          Miami
# 9   1610612749          MIL          Bucks       1968.0      Milwaukee
# 10  1610612750          MIN   Timberwolves       1989.0      Minnesota
# 11  1610612751          BKN           Nets       1976.0       Brooklyn
# ...

# %%
team_history=pd.read_csv('D:/Datasets/NBA/csv/team_history.csv')

# %%
team_history
# Out:
#        team_id               city       nickname  year_founded  \
# 0   1610612737            Atlanta          Hawks          1968
# 1   1610612737          St. Louis          Hawks          1955
# 2   1610612737          Milwaukee          Hawks          1951
# 3   1610612737         Tri-Cities     Blackhawks          1949
# 4   1610612741            Chicago          Bulls          1966
# 5   1610612742             Dallas      Mavericks          1980
# 6   1610612743             Denver        Nuggets          1976
# 7   1610612744       Golden State       Warriors          1971
# 8   1610612744      San Francisco       Warriors          1962
# 9   1610612744       Philadelphia       Warriors          1946
# 10  1610612745            Houston        Rockets          1971
# 11  1610612745          San Diego        Rockets          1967
# 12  1610612746        Los Angeles       Clippers          1984
# 13  1610612746          San Diego       Clippers          1978
# ...
